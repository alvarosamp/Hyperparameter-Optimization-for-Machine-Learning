# %% [markdown]
# ## Randomized Search with Scikit-Optimize
#
# In this notebook, we will perform **Randomized Search** to select the best **hyperparameters** for a Gradient Boosting Classifier, using the open source Python package [Scikit-Optimize]
#
# The randomized search is performed with the class [dummy_minimize]
#
# ### Procedure
#
# To tune the hyper-parameters of our model we need to:
#
# - define a model
# - decide which parameters to optimize
# - define the objective function we want to minimize.
#
# ### NOTE
#
# Scikit-Optimize will always **minimize** the objective function, so if we want to maximize a function, for example the roc-auc, we need to **negate** the metric. Thus, instead of maximizing the roc-auc, we minimize the -roc-auc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score, train_test_split

from skopt import dummy_minimize # for the randomized search

# for the analysis
from skopt.plots import (
    plot_convergence,
    plot_evaluations,
)

from skopt.space import Real, Integer, Categorical
from skopt.utils import use_named_args

# %%
breast_cancer_X, breast_cancer_y = load_breast_cancer(return_X_y=True)
X = pd.DataFrame(breast_cancer_X)
y = pd.Series(breast_cancer_y).map({0:1, 1:0})

X.head()
# Out:
#       0      1       2       3        4        5       6        7       8   \
# 0  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 2  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 3  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 4  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
#
#         9   ...     20     21      22      23      24      25      26      27  \
# 0  0.07871  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.05667  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.05999  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.09744  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.05883  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        28       29
# 0  0.4601  0.11890
# ...

# %%
y.value_counts() / len(y)
# Out:
# 0    0.627417
# 1    0.372583
# Name: count, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0)

X_train.shape, X_test.shape
# Out:
# ((398, 30), (171, 30))

# %% [markdown]
# ## Define the hyperparamter space

# %%
param_grid = [
    Integer(10, 120, name="n_estimators"),
    Integer(1, 5, name="max_depth"),
    Real(0.0001, 0.1, prior='log-uniform', name='learning_rate'),
    Real(0.001, 0.999, prior='log-uniform', name="min_samples_split"),
    Categorical(['log_loss', 'exponential'], name="loss"),
]


type(param_grid)
# Out:
# list

# %%
## Define the mdoel
gbm = GradientBoostingClassifier(random_state = 42)

# %% [markdown]
# ## Define the objective function

# %%
@use_named_args(param_grid)
def objective(**params):
    gbm.set_params(**params)

    value = np.mean(
        cross_val_score(
            gbm,
            X_train,
            y_train,
            cv = 3,
            n_jobs = -4,
            scoring = 'accuracy',
        
        )
    )

    return -value

# %% [markdown]
# ##Randomized Search

# %%
##dumy_minimize performs the randomized search

search = dummy_minimize(
    objective,
    param_grid,
    n_calls = 50,
    random_state = 42,
)

# %%
"Best score=%.4f" % search.fun
# Out:
# 'Best score=-0.9447'

# %%
print("""Best parameters:
=========================
- n_estimators = %d
- max-depth = %d
- min_samples_split = %.3f
- learning_rate = %.3f
- loss = %s""" % (search.x[0], 
                search.x[1],
                search.x[2],
                search.x[3],
                search.x[4],
               ))
# Out:
# Best parameters:
# ...
# - n_estimators = 89
# - max-depth = 3
# - min_samples_split = 0.037
# - learning_rate = 0.016
# - loss = exponential

# %%
#Evaluaete convergence of the search
plot_convergence(search)
# Out:
# <Axes: title={'center': 'Convergence plot'}, xlabel='Number of calls $n$', ylabel='$\\min f(x)$ after $n$ calls'>

# %% [markdown]
# ## Evaluation order

# %%
dim_names = ['n_estimators', 'max_depth', 'learning_rate', 'min_samples_split', 'loss']

# %%
plot_evaluations(search, dimensions=dim_names)
plt.show()

# %% [markdown]
# ## The search class

# %%
#Extract the best parameters
tmp = pd.concat([
    pd.DataFrame(search.x_iters, columns=dim_names),
    pd.Series(search.func_vals, name='score')
], axis=1)
tmp.columns = dim_names + ['accuracy']
tmp.sort_values(by='accuracy', ascending=True, inplace = True)
tmp.head()
# Out:
#     n_estimators  max_depth  learning_rate  min_samples_split         loss  \
# 44            89          3       0.037066           0.016344  exponential
# 18            50          4       0.038843           0.074067     log_loss
# 23           105          4       0.052808           0.005595     log_loss
# 25            95          4       0.061531           0.265467  exponential
# 17            90          3       0.023471           0.065708  exponential
#
#     accuracy
# 44 -0.944729
# 18 -0.934723
# 23 -0.934704
# 25 -0.934704
# 17 -0.932198

# %%
tmp.sort_values(by = 'n_estimators', ascending = False, inplace = True)
tmp.head()
# Out:
#     n_estimators  max_depth  learning_rate  min_samples_split         loss  \
# 15           118          1       0.000774           0.003131     log_loss
# 4            117          1       0.000748           0.068437     log_loss
# 46           108          1       0.009784           0.001036     log_loss
# 23           105          4       0.052808           0.005595     log_loss
# 5            101          4       0.001256           0.023335  exponential
#
#     accuracy
# 15 -0.625636
# 4  -0.625636
# 46 -0.919534
# 23 -0.934704
# 5  -0.625636
